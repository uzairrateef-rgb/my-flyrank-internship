# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uzairrateef-rgb/my-flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/uzairrateef-rgb/my-flyrank-internship.git
# %cd my-flyrank-internship
# Out:
# Cloning into 'my-flyrank-internship'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 114 (delta 28), reused 101 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (114/114), 1.84 MiB | 14.46 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/my-flyrank-internship/my-flyrank-internship

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"Lane: Content Refresh Prioritization."
"I'm going with this lane instead of freestyling because the starter dataset (content_refresh_anonymized.csv) is built specifically for it, and the reference pipeline (scripts/01–05) already shows the full path from raw data to a ranked recommendation. That means I can focus on understanding the workflow framing, baseline, model, evaluation instead of spending Week 1 hunting for a dataset. It's also a real problem: teams manage far more pages than they have time to rewrite, so knowing which ones to fix first has obvious value."
# Out:
# "I'm going with this lane instead of freestyling because the starter dataset (content_refresh_anonymized.csv) is built specifically for it, and the reference pipeline (scripts/01–05) already shows the full path from raw data to a ranked recommendation. That means I can focus on understanding the workflow framing, baseline, model, evaluation instead of spending Week 1 hunting for a dataset. It's also a real problem: teams manage far more pages than they have time to rewrite, so knowing which ones to fix first has obvious value."

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"Decision improved: which pages a content team should review/update first, out of thousands.Who acts on it: SEO/content strategists and the writers they assign work to. Cost of a wrong call: if the model flags a page as high-priority and it isn't, the team wastes writer-hours on a page that wasn't actually losing traffic a false positive cost measured in time. If it misses a page that's genuinely declining, that page keeps losing search visibility/traffic until someone catches it manually a false negative cost measured in lost visibility. Neither error is catastrophic on its own, which is why this is decision-support, not an automated action."

"Looking at trend_direction across all 30,000 pages, 54.2% are trending down, compared to just 14.6% trending up and 19.9% holding stable. Among declining pages, the median traffic drop is 33.5%, and a quarter of them have dropped more than 62.6%, this isn't a marginal problem, it's the majority state of the content. That said, the data isn't perfectly clean: trend_pct has extreme outliers (values in the thousands of percent) that need to be handled carefully rather than averaged directly, and columns like provider_used (71% missing) and word_count (26% missing) will need imputation or exclusion before modeling."
# Out:
# "Looking at trend_direction across all 30,000 pages, 54.2% are trending down, compared to just 14.6% trending up and 19.9% holding stable. Among declining pages, the median traffic drop is 33.5%, and a quarter of them have dropped more than 62.6%, this isn't a marginal problem, it's the majority state of the content. That said, the data isn't perfectly clean: trend_pct has extreme outliers (values in the thousands of percent) that need to be handled carefully rather than averaged directly, and columns like provider_used (71% missing) and word_count (26% missing) will need imputation or exclusion before modeling."

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.shape)
print(df.columns.tolist())

print(df['trend_direction'].value_counts(normalize=True) * 100)
print()
print(df['trend_pct'].describe())
print()
print(df.isna().mean().sort_values(ascending=False).head(10) * 100)
# Out:
# (30000, 44)
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
# trend_direction
# down      54.206667
# stable    19.873333
# up        14.626667
# new        7.453333
# flat       3.840000
# Name: proportion, dtype: float64
#
# count    26612.000000
# mean        -4.785969
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

"What I can say: with 54% of pages trending down and typical drops around a third of prior traffic, there's a real, observable prioritization problem here, decision-support for which pages to review first. What I can't say: that a page's decline was caused by staleness or any single factor, or that fixing a flagged page will reverse the trend, trend_pct's outliers alone show this data needs care before drawing firm conclusions, let alone predicting Google's behavior."
# Out:
# "What I can say: with 54% of pages trending down and typical drops around a third of prior traffic, there's a real, observable prioritization problem here — decision-support for which pages to review first. What I can't say: that a page's decline was caused by staleness or any single factor, or that fixing a flagged page will reverse the trend — trend_pct's outliers alone show this data needs care before drawing firm conclusions, let alone predicting Google's behavior."

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
